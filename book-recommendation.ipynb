# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv', low_memory=False)  
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books.sample(5)
# Out:
#               ISBN                             Book-Title     Book-Author  \
# 445     1857938011                  A-Z of Behaving Badly       Simon Nye
# 163385  0333186443                    The machine-gunners  Robert Westall
# 8597    1863738487                                   Crew    Tony McGowan
# 208268  222607533X                       Terre somnanbule       Couto Mia
# 216681  0380815176  Much Ado About Love (An Avon Romance)    Malia Martin
#
#        Year-Of-Publication          Publisher  \
# 445                   1996   Trafalgar Square
# 163385                1975          Macmillan
# 8597                  1995  Allen &amp; Unwin
# 208268                2000       Albin Michel
# 216681                2000               Avon
#
#                                               Image-URL-S  \
# 445     http://images.amazon.com/images/P/1857938011.0...
# 163385  http://images.amazon.com/images/P/0333186443.0...
# 8597    http://images.amazon.com/images/P/1863738487.0...
# ...

# %% [markdown]
# ## Collaborative Filtering Based Recommender System

# %%
# ratings_with_name['Book-Rating'] = pd.to_numeric(ratings_with_name['Book-Rating'], errors='coerce')
# ratings_with_name.dropna(subset=['Book-Rating'], inplace=True)

avg_rating_df = ratings_with_name.groupby('Book-Title').sum()['Book-Rating'].reset_index()

avg_rating_df.rename(columns={'Book-Rating':'total_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  total_rating
# 0        A Light in the Storm: The Civil War Diary of ...             9
# 1                                   Always Have Popsicles             0
# 2                    Apple Magic (The Collector's series)             0
# 3        Ask Lily (Young Women of Faith: Lily Series, ...             8
# 4        Beyond IBM: Leadership Marketing and Finance ...             0
# ...                                                   ...           ...
# 241066                                      Ã?Â?lpiraten.             0
# 241067                     Ã?Â?rger mit Produkt X. Roman.            21
# 241068                                Ã?Â?sterlich leben.             7
# 241069                              Ã?Â?stlich der Berge.             8
# 241070                                  Ã?Â?thique en toc             8
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df = popular_df[popular_df['num_ratings']>=250].head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','total_rating']]

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0                                                 1984
# 9                                  1st to Die: A Novel
# 11                                          2nd Chance
# 15                                  A Bend in the Road
# 21   A Child Called \It\": One Child's Courage to S...
# 23           A Heartbreaking Work of Staggering Genius
# 24   A Is for Alibi (Kinsey Millhone Mysteries (Pap...
# 25                                  A Map of the World
# 28                                     A Painted House
# 33                             A Prayer for Owen Meany
# 35                                      A Time to Kill
# 42                                  A Walk to Remember
# 46                                A Widow for One Year
# 50                                      ANGELA'S ASHES
# 52                                         About a Boy
# 59                                            Airframe
# ...

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
rated = x[x].index

# %%
ratedfiltered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(rated)]

# %%
ratedfiltered_rating.sample(5)
# Out:
#         User-ID        ISBN  Book-Rating  \
# 854076   185384  1930009062           10
# 828592   131046  0761132589            0
# 799111   268110  0743417917            0
# 357947     6575  0140011722            8
# 464503    11676  0395544092            0
#
#                                      Book-Title             Book-Author  \
# 854076              Come Back, Wherever You Are  Lenora Mattingly Weber
# 828592  Stitch 'N Bitch: The Knitter's Handbook          Debbie Stoller
# 799111          The Husband Hunt (Sonnet Books)          Jillian Hunter
# 357947                             Laughing Gas         P. G. Wodehouse
# 464503        Best American Short Stories, 1991             Alice Adams
#
#        Year-Of-Publication                 Publisher  \
# 854076                1999  Image Cascade Publishing
# 828592                2003        Workman Publishing
# 799111                2002                    Pocket
# 357947                1991             Penguin Books
# ...

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('Thinner')
# Out:
# [['The Dark Half',
#   'Stephen King',
#   'http://images.amazon.com/images/P/0451167317.01.MZZZZZZZ.jpg'],
#  ['Misery',
#   'Stephen King',
#   'http://images.amazon.com/images/P/0451153553.01.MZZZZZZZ.jpg'],
#  ['The Tommyknockers',
#   'Stephen King',
#   'http://images.amazon.com/images/P/0451156609.01.MZZZZZZZ.jpg'],
#  ["Gerald's Game",
#   'Stephen King',
#   'http://images.amazon.com/images/P/0451176464.01.MZZZZZZZ.jpg']]

# %%
import pickle

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(popular_df,open('popular.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
print("numpy", np.__version__)
print("pandas", pd.__version__)
# Out:
# numpy 1.26.4
# pandas 2.1.4

# %%
popular_df.to_csv('test_data.csv', index=False)
